# %%
import pandas as pd
import os

# %%
CSV_PATH = os.path.join("..","..","source", "Sales_Dataset.csv")
if os.path.exists(CSV_PATH):
    df = pd.read_csv(CSV_PATH)
    print(df.head())
else:
    print(f"File not found: {CSV_PATH}")
# Out:
# File not found: ..\source\Sales_Dataset.csv
